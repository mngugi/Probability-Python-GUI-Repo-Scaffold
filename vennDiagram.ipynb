# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

# Events
# Let's say:
# A = "Roll is 5"
# B = "Roll is odd"

# Define sizes:
# - The universal set is {1, 2, 3, 4, 5, 6}
# - A has 1 outcome: {5}
# - B has 3 outcomes: {1, 3, 5}
# Intersection A ∩ B = {5} (1 outcome)

# Sizes for Venn diagram (in terms of probabilities)
p_A = 1/6
p_B = 3/6
p_A_and_B = 1/6

# Create the diagram
plt.figure(figsize=(5,5))
venn = venn2(subsets=(p_A - p_A_and_B,  # A only
                      p_B - p_A_and_B,  # B only
                      p_A_and_B),       # Intersection
             set_labels=('A: Roll is 5', 'B: Roll is odd'))

# Title
plt.title("Conditional Probability Example: P(A|B)", fontsize=14)
plt.show()

# %% [markdown]
# Here’s the Venn diagram:
#
# Circle A: All outcomes where the roll is 5.
#
# Circle B: All outcomes where the roll is odd.
#
# The overlap: The single outcome {5}, which belongs to both sets.
#
# When we calculate
# 𝑃(𝐴∣𝐵)
# P(A∣B), we’re looking only inside circle B and asking, “What fraction of this is also in A?” — which is why it’s
# 1/3
